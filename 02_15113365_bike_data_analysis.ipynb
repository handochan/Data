# %% [markdown]
# <a href="https://colab.research.google.com/github/handochan/Data/blob/master/02_15113365_bike_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googel Drive Mount
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
cd /content/gdrive/My Drive/4학년2학기/데이터를활용한스타트업
# Out:
# /content/gdrive/My Drive/4학년2학기/데이터를활용한스타트업

# %%
df = pd.read_csv('bike_data.csv')

# %%
df.head()
# Out:
#           datetime  season  holiday  ...  casual  registered  count
# 0  2018-01-01 0:00       1        0  ...       3          13     16
# 1  2018-01-01 1:00       1        0  ...       8          32     40
# 2  2018-01-01 2:00       1        0  ...       5          27     32
# 3  2018-01-01 3:00       1        0  ...       3          10     13
# 4  2018-01-01 4:00       1        0  ...       0           1      1
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#                datetime  season  holiday  ...  casual  registered  count
# 10881  2019-12-19 19:00       4        0  ...       7         329    336
# 10882  2019-12-19 20:00       4        0  ...      10         231    241
# 10883  2019-12-19 21:00       4        0  ...       4         164    168
# 10884  2019-12-19 22:00       4        0  ...      12         117    129
# 10885  2019-12-19 23:00       4        0  ...       4          84     88
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
data = df[['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
       'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count']]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data = data.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Reds')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.describe()
# Out:
#              season       holiday  ...    registered         count
# count  10886.000000  10886.000000  ...  10886.000000  10886.000000
# mean       2.506614      0.028569  ...    155.552177    191.574132
# std        1.116174      0.166599  ...    151.039033    181.144454
# min        1.000000      0.000000  ...      0.000000      1.000000
# 25%        2.000000      0.000000  ...     36.000000     42.000000
# 50%        3.000000      0.000000  ...    118.000000    145.000000
# 75%        4.000000      0.000000  ...    222.000000    284.000000
# max        4.000000      1.000000  ...    886.000000    977.000000
#
# [8 rows x 11 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                datetime  season  holiday  ...  casual  registered  count
# 0       2018-01-01 0:00       1        0  ...       3          13     16
# 1       2018-01-01 1:00       1        0  ...       8          32     40
# 2       2018-01-01 2:00       1        0  ...       5          27     32
# 3       2018-01-01 3:00       1        0  ...       3          10     13
# 4       2018-01-01 4:00       1        0  ...       0           1      1
# ...                 ...     ...      ...  ...     ...         ...    ...
# 10881  2019-12-19 19:00       4        0  ...       7         329    336
# 10882  2019-12-19 20:00       4        0  ...      10         231    241
# 10883  2019-12-19 21:00       4        0  ...       4         164    168
# 10884  2019-12-19 22:00       4        0  ...      12         117    129
# 10885  2019-12-19 23:00       4        0  ...       4          84     88
#
# [10886 rows x 12 columns]>

# %%
df.corr()
# Out:
#               season   holiday  workingday  ...    casual  registered     count
# season      1.000000  0.029368   -0.008126  ...  0.096758    0.164011  0.163439
# holiday     0.029368  1.000000   -0.250491  ...  0.043799   -0.020956 -0.005393
# workingday -0.008126 -0.250491    1.000000  ... -0.319111    0.119460  0.011594
# weather     0.008879 -0.007074    0.033772  ... -0.135918   -0.109340 -0.128655
# temp        0.258689  0.000295    0.029966  ...  0.467097    0.318571  0.394454
# atemp       0.264744 -0.005215    0.024660  ...  0.462067    0.314635  0.389784
# humidity    0.190610  0.001929   -0.010880  ... -0.348187   -0.265458 -0.317371
# windspeed  -0.147121  0.008409    0.013373  ...  0.092276    0.091052  0.101369
# casual      0.096758  0.043799   -0.319111  ...  1.000000    0.497250  0.690414
# registered  0.164011 -0.020956    0.119460  ...  0.497250    1.000000  0.970948
# count       0.163439 -0.005393    0.011594  ...  0.690414    0.970948  1.000000
#
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data = df.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Reds')

# %%
df.temp.mean()
# Out:
# 20.230859819952173

# %%
df.holiday.mean()
# Out:
# 0.02856880396839978

# %%
df.groupby('season')['count'].mean()
# Out:
# season
# 1    116.343261
# 2    215.251372
# 3    234.417124
# 4    198.988296
# Name: count, dtype: float64

# %%
df.groupby('time')['count'].mean()
# Out:
# time
# 2020-10-25 00:00:00     55.138462
# 2020-10-25 01:00:00     33.859031
# 2020-10-25 02:00:00     22.899554
# 2020-10-25 03:00:00     11.757506
# 2020-10-25 04:00:00      6.407240
# 2020-10-25 05:00:00     19.767699
# 2020-10-25 06:00:00     76.259341
# 2020-10-25 07:00:00    213.116484
# 2020-10-25 08:00:00    362.769231
# 2020-10-25 09:00:00    221.780220
# 2020-10-25 10:00:00    175.092308
# 2020-10-25 11:00:00    210.674725
# 2020-10-25 12:00:00    256.508772
# 2020-10-25 13:00:00    257.787281
# 2020-10-25 14:00:00    243.442982
# 2020-10-25 15:00:00    254.298246
# 2020-10-25 16:00:00    316.372807
# 2020-10-25 17:00:00    468.765351
# 2020-10-25 18:00:00    430.859649
# 2020-10-25 19:00:00    315.278509
# 2020-10-25 20:00:00    228.517544
# 2020-10-25 21:00:00    173.370614
# 2020-10-25 22:00:00    133.576754
# 2020-10-25 23:00:00     89.508772
# Name: count, dtype: float64

# %%
df['count'].mean()
# Out:
# 191.57413191254824

# %%
df['count'].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: count, dtype: float64

# %%
df['datetime'].describe()
# Out:
# count               10886
# unique              10886
# top       2019-12-10 9:00
# freq                    1
# Name: datetime, dtype: object

# %%
df['season'].value_counts()
# Out:
# 4    2734
# 3    2733
# 2    2733
# 1    2686
# Name: season, dtype: int64

# %%
df['holiday'].value_counts()
# Out:
# 0    10575
# 1      311
# Name: holiday, dtype: int64

# %%
df['workingday'].value_counts()
# Out:
# 1    7412
# 0    3474
# Name: workingday, dtype: int64

# %%
df['workingday'].mean()
# Out:
# 0.6808745177291935

# %%
df['weather'].value_counts()
# Out:
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64

# %%
df['temp'].describe()
# Out:
# count    10886.00000
# mean        20.23086
# std          7.79159
# min          0.82000
# 25%         13.94000
# 50%         20.50000
# 75%         26.24000
# max         41.00000
# Name: temp, dtype: float64

# %%
df['atemp'].describe()
# Out:
# count    10886.000000
# mean        23.655084
# std          8.474601
# min          0.760000
# 25%         16.665000
# 50%         24.240000
# 75%         31.060000
# max         45.455000
# Name: atemp, dtype: float64

# %%
df['humidity'].describe()
# Out:
# count    10886.000000
# mean        61.886460
# std         19.245033
# min          0.000000
# 25%         47.000000
# 50%         62.000000
# 75%         77.000000
# max        100.000000
# Name: humidity, dtype: float64

# %%
df['windspeed'].describe()
# Out:
# count    10886.000000
# mean        12.799395
# std          8.164537
# min          0.000000
# 25%          7.001500
# 50%         12.998000
# 75%         16.997900
# max         56.996900
# Name: windspeed, dtype: float64

# %%
df['casual'].describe()
# Out:
# count    10886.000000
# mean        36.021955
# std         49.960477
# min          0.000000
# 25%          4.000000
# 50%         17.000000
# 75%         49.000000
# max        367.000000
# Name: casual, dtype: float64

# %%
df['registered'].describe()
# Out:
# count    10886.000000
# mean       155.552177
# std        151.039033
# min          0.000000
# 25%         36.000000
# 50%        118.000000
# 75%        222.000000
# max        886.000000
# Name: registered, dtype: float64

# %%
df.loc[:100,['casual', 'registered']]
# Out:
#      casual  registered
# 0         3          13
# 1         8          32
# 2         5          27
# 3         3          10
# 4         0           1
# ..      ...         ...
# 96        0           3
# 97        0          33
# 98        1          87
# 99        3         192
# 100       6         109
#
# [101 rows x 2 columns]

# %%
df.loc[:5,['datetime']]
# Out:
#           datetime
# 0  2018-01-01 0:00
# 1  2018-01-01 1:00
# 2  2018-01-01 2:00
# 3  2018-01-01 3:00
# 4  2018-01-01 4:00
# 5  2018-01-01 5:00

# %%
df['date'] = df['datetime'].str.split(" ").str[0]

# %%
df.loc[:5,['date']]
# Out:
#          date
# 0  2018-01-01
# 1  2018-01-01
# 2  2018-01-01
# 3  2018-01-01
# 4  2018-01-01
# 5  2018-01-01

# %%
df['time'] = df['datetime'].str.split(" ").str[1]

# %%
df.loc[:5,['time']]
# Out:
#    time
# 0  0:00
# 1  1:00
# 2  2:00
# 3  3:00
# 4  4:00
# 5  5:00

# %%
df['year'] = df['date'].str.split("-").str[0]

# %%
df.loc[:5, ['year']]
# Out:
#    year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018
# 5  2018

# %%
df['month'] = df['date'].str.split("-").str[1]

# %%
df.loc[:5,['month']]
# Out:
#   month
# 0    01
# 1    01
# 2    01
# 3    01
# 4    01
# 5    01

# %%
df['day'] = df['date'].str.split("-").str[2]

# %%
df.loc[:5,['day']]
# Out:
#   day
# 0  01
# 1  01
# 2  01
# 3  01
# 4  01
# 5  01

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'date', 'time', 'year', 'month', 'day'],
#       dtype='object')

# %%
df.groupby('season')['count'].mean()
# Out:
# season
# 1    116.343261
# 2    215.251372
# 3    234.417124
# 4    198.988296
# Name: count, dtype: float64

# %%
df.groupby('year')['count'].mean()
# Out:
# year
# 2018    144.223349
# 2019    238.560944
# Name: count, dtype: float64

# %%
df.groupby('holiday')['count'].mean()
# Out:
# holiday
# 0    191.741655
# 1    185.877814
# Name: count, dtype: float64

# %%
df.groupby('month')['count'].mean()
# Out:
# month
# 01     90.366516
# 02    110.003330
# 03    148.169811
# 04    184.160616
# 05    219.459430
# 06    242.031798
# 07    235.325658
# 08    234.118421
# 09    233.805281
# 10    227.699232
# 11    193.677278
# 12    175.614035
# Name: count, dtype: float64

# %%
df.groupby('workingday')['count'].mean()
# Out:
# workingday
# 0    188.506621
# 1    193.011873
# Name: count, dtype: float64

# %%
df.groupby('weather')['count'].mean()
# Out:
# weather
# 1    205.236791
# 2    178.955540
# 3    118.846333
# 4    164.000000
# Name: count, dtype: float64

# %%
df.groupby('time')['count'].mean()
# Out:
# time
# 0:00      55.138462
# 10:00    175.092308
# 11:00    210.674725
# 12:00    256.508772
# 13:00    257.787281
# 14:00    243.442982
# 15:00    254.298246
# 16:00    316.372807
# 17:00    468.765351
# 18:00    430.859649
# 19:00    315.278509
# 1:00      33.859031
# 20:00    228.517544
# 21:00    173.370614
# 22:00    133.576754
# 23:00     89.508772
# 2:00      22.899554
# 3:00      11.757506
# 4:00       6.407240
# 5:00      19.767699
# 6:00      76.259341
# 7:00     213.116484
# 8:00     362.769231
# 9:00     221.780220
# Name: count, dtype: float64

# %%
df.groupby('year')['count'].sum()
# Out:
# year
# 2018     781979
# 2019    1303497
# Name: count, dtype: int64

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('month')['count'].sum().plot()

# %%
sns.barplot(x='month', y='count', data = df)

# %%
df['count'].plot()

# %%
df['casual'].plot()

# %%
 df['registered'].plot()

# %%
import seaborn as sns

# %%
spring = df[df['season']==1]
summer = df[df['season']==2]
fall = df[df['season']==3]
winter = df[df['season']==4]

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'date', 'time', 'year', 'month', 'day'],
#       dtype='object')

# %%
plt.plot(df['season'], df['count'], 'o')

# %%
plt.scatter(df['temp'], df['count'])

# %%
plt.boxplot([df[df['year']=='2018']['count'], 
             df[df['year']=='2019']['count']],
            labels=['2018', '2019'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f474d79c518>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f474d79cef0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f474d7a99b0>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f474d7a9630>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f474d79c7f0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f474d7b6470>]}

# %%
ax = sns.distplot(df['count'], rug=True)
ax.set_title('count')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'count')

# %%
sns.countplot('weather', data=df)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(df['temp'], df['count'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x='atemp', y='count', data=df)

# %%
sns.regplot(x='humidity', y='count', data=df)

# %%
sns.jointplot(x='temp', y='count', data=df)

# %%
sns.kdeplot(df['temp'], df['count'], shade=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(x='season', y='count', data=df)

# %%
sns.boxplot(x='season', y='count', data = df)

# %%
sns.violinplot(x='season', y='count', data=df)

# %%
sns.boxplot(df['count'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = sns.pairplot(df)

# %%
sns.lmplot(x='temp', y='count', data=df)

# %%
df['count'].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: count, dtype: float64

# %%
IQR = df[df['count']>= 42]

# %%
IQR = IQR[IQR['count']<=284]

# %%
IQR['count'].describe()
# Out:
# count    5472.000000
# mean      149.826937
# std        68.392944
# min        42.000000
# 25%        90.000000
# 50%       145.000000
# 75%       205.000000
# max       284.000000
# Name: count, dtype: float64

# %%
sns.distplot(IQR['count'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.regplot(x='temp', y='count', data=IQR)

# %%
IQR.corr()
# Out:
#               season   holiday  workingday  ...    casual  registered     count
# season      1.000000  0.014894   -0.038768  ...  0.094298    0.159478  0.163794
# holiday     0.014894  1.000000   -0.244697  ...  0.023521   -0.027860 -0.014983
# workingday -0.038768 -0.244697    1.000000  ... -0.167927    0.228724  0.131591
# weather     0.050103 -0.012597    0.035871  ... -0.114711   -0.089708 -0.113153
# temp        0.268130 -0.028138    0.080159  ...  0.533577    0.167178  0.319860
# atemp       0.274277 -0.035920    0.075344  ...  0.533065    0.170336  0.322293
# humidity    0.261433  0.005850   -0.113968  ... -0.191888   -0.148250 -0.187784
# windspeed  -0.178854  0.034752    0.041952  ...  0.044606    0.021771  0.033175
# casual      0.094298  0.023521   -0.167927  ...  1.000000    0.359558  0.637639
# registered  0.159478 -0.027860    0.228724  ...  0.359558    1.000000  0.948086
# count       0.163794 -0.014983    0.131591  ...  0.637639    0.948086  1.000000
#
# ...

# %%
df.groupby('season')['count'].sum()
# Out:
# season
# 1    312498
# 2    588282
# 3    640662
# 4    544034
# Name: count, dtype: int64

# %%
df.groupby('season')['count'].mean()
# Out:
# season
# 1    116.343261
# 2    215.251372
# 3    234.417124
# 4    198.988296
# Name: count, dtype: float64

# %%
df.groupby('season')['weather'].mean()
# Out:
# season
# 1    1.424423
# 2    1.422978
# 3    1.366630
# 4    1.459766
# Name: weather, dtype: float64

# %%
df.groupby('weather')['count'].mean()
# Out:
# weather
# 1    205.236791
# 2    178.955540
# 3    118.846333
# 4    164.000000
# Name: count, dtype: float64

# %%
df.groupby('weather')['temp'].mean()
# Out:
# weather
# 1    20.557122
# 2    19.614608
# 3    19.546356
# 4     8.200000
# Name: temp, dtype: float64

# %%
df.groupby('season')['temp'].mean()
# Out:
# season
# 1    12.530491
# 2    22.823483
# 3    28.789111
# 4    16.649239
# Name: temp, dtype: float64

# %%
df.groupby('time')['count'].mean()
# Out:
# time
# 0:00      55.138462
# 10:00    175.092308
# 11:00    210.674725
# 12:00    256.508772
# 13:00    257.787281
# 14:00    243.442982
# 15:00    254.298246
# 16:00    316.372807
# 17:00    468.765351
# 18:00    430.859649
# 19:00    315.278509
# 1:00      33.859031
# 20:00    228.517544
# 21:00    173.370614
# 22:00    133.576754
# 23:00     89.508772
# 2:00      22.899554
# 3:00      11.757506
# 4:00       6.407240
# 5:00      19.767699
# 6:00      76.259341
# 7:00     213.116484
# 8:00     362.769231
# 9:00     221.780220
# Name: count, dtype: float64

# %%
df.groupby('time')['count'].mean().plot()

# %%
workday = df[df['workingday']==1]

# %%
workday.groupby('time')['count'].mean().plot()

# %%
no_workday = df[df['workingday']==0]

# %%
no_workday.groupby('time')['count'].mean().plot()

# %%
sns.barplot(x='time', y='count', data = workday)

# %%
import datetime

# %%
workday['time'] = pd.to_datetime(workday['time'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df.groupby('time')['count'].mean().plot()

# %%
workday.groupby('time')['count'].mean()
# Out:
# time
# 2020-10-25 00:00:00     36.732258
# 2020-10-25 01:00:00     16.003236
# 2020-10-25 02:00:00      8.436066
# 2020-10-25 03:00:00      4.892734
# 2020-10-25 04:00:00      5.363636
# 2020-10-25 05:00:00     24.529032
# 2020-10-25 06:00:00    102.577419
# 2020-10-25 07:00:00    290.690323
# 2020-10-25 08:00:00    479.945161
# 2020-10-25 09:00:00    242.293548
# 2020-10-25 10:00:00    133.596774
# 2020-10-25 11:00:00    157.019355
# 2020-10-25 12:00:00    199.347267
# 2020-10-25 13:00:00    197.160772
# 2020-10-25 14:00:00    180.366559
# 2020-10-25 15:00:00    198.627010
# 2020-10-25 16:00:00    292.466238
# 2020-10-25 17:00:00    529.209003
# 2020-10-25 18:00:00    495.485531
# 2020-10-25 19:00:00    349.282958
# 2020-10-25 20:00:00    249.363344
# 2020-10-25 21:00:00    184.855305
# 2020-10-25 22:00:00    138.344051
# 2020-10-25 23:00:00     88.996785
# Name: count, dtype: float64

# %%
workday.groupby('time')['count'].mean().plot()

# %%
workday.groupby('time')['count'].mean()
# Out:
# time
# 2020-10-25 00:00:00     36.732258
# 2020-10-25 01:00:00     16.003236
# 2020-10-25 02:00:00      8.436066
# 2020-10-25 03:00:00      4.892734
# 2020-10-25 04:00:00      5.363636
# 2020-10-25 05:00:00     24.529032
# 2020-10-25 06:00:00    102.577419
# 2020-10-25 07:00:00    290.690323
# 2020-10-25 08:00:00    479.945161
# 2020-10-25 09:00:00    242.293548
# 2020-10-25 10:00:00    133.596774
# 2020-10-25 11:00:00    157.019355
# 2020-10-25 12:00:00    199.347267
# 2020-10-25 13:00:00    197.160772
# 2020-10-25 14:00:00    180.366559
# 2020-10-25 15:00:00    198.627010
# 2020-10-25 16:00:00    292.466238
# 2020-10-25 17:00:00    529.209003
# 2020-10-25 18:00:00    495.485531
# 2020-10-25 19:00:00    349.282958
# 2020-10-25 20:00:00    249.363344
# 2020-10-25 21:00:00    184.855305
# 2020-10-25 22:00:00    138.344051
# 2020-10-25 23:00:00     88.996785
# Name: count, dtype: float64

# %%
no_workday['time'] = pd.to_datetime(no_workday['time'])
no_workday.groupby('time')['count'].mean().plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
no_workday.groupby('time')['count'].mean()
# Out:
# time
# 2020-10-25 00:00:00     94.489655
# 2020-10-25 01:00:00     71.910345
# 2020-10-25 02:00:00     53.748252
# 2020-10-25 03:00:00     25.534722
# 2020-10-25 04:00:00      8.544828
# 2020-10-25 05:00:00      9.373239
# 2020-10-25 06:00:00     19.993103
# 2020-10-25 07:00:00     47.268966
# 2020-10-25 08:00:00    112.255172
# 2020-10-25 09:00:00    177.924138
# 2020-10-25 10:00:00    263.806897
# 2020-10-25 11:00:00    325.386207
# 2020-10-25 12:00:00    379.110345
# 2020-10-25 13:00:00    387.820690
# 2020-10-25 14:00:00    378.731034
# 2020-10-25 15:00:00    373.703448
# 2020-10-25 16:00:00    367.648276
# 2020-10-25 17:00:00    339.124138
# 2020-10-25 18:00:00    292.248276
# 2020-10-25 19:00:00    242.344828
# 2020-10-25 20:00:00    183.806897
# 2020-10-25 21:00:00    148.737931
# 2020-10-25 22:00:00    123.351724
# 2020-10-25 23:00:00     90.606897
# Name: count, dtype: float64

# %%
sns.scatterplot(x='temp', y='count', data=df)

# %%
workday.groupby('time')['casual'].mean().plot()

# %%
workday.groupby('time')['casual'].mean()
# Out:
# time
# 2020-10-25 00:00:00     7.174194
# 2020-10-25 01:00:00     3.446602
# 2020-10-25 02:00:00     2.101639
# 2020-10-25 03:00:00     0.878893
# 2020-10-25 04:00:00     0.734007
# 2020-10-25 05:00:00     1.287097
# 2020-10-25 06:00:00     4.280645
# 2020-10-25 07:00:00    11.941935
# 2020-10-25 08:00:00    22.045161
# 2020-10-25 09:00:00    24.045161
# 2020-10-25 10:00:00    30.209677
# 2020-10-25 11:00:00    37.100000
# 2020-10-25 12:00:00    40.408360
# 2020-10-25 13:00:00    42.215434
# 2020-10-25 14:00:00    44.681672
# 2020-10-25 15:00:00    45.180064
# 2020-10-25 16:00:00    47.745981
# 2020-10-25 17:00:00    56.508039
# 2020-10-25 18:00:00    49.414791
# 2020-10-25 19:00:00    40.456592
# 2020-10-25 20:00:00    30.591640
# 2020-10-25 21:00:00    24.090032
# 2020-10-25 22:00:00    19.266881
# 2020-10-25 23:00:00    13.183280
# Name: casual, dtype: float64

# %%
workday.groupby('time')['registered'].mean().plot()

# %%
workday.groupby('time')['registered'].mean()
# Out:
# time
# 2020-10-25 00:00:00     29.558065
# 2020-10-25 01:00:00     12.556634
# 2020-10-25 02:00:00      6.334426
# 2020-10-25 03:00:00      4.013841
# 2020-10-25 04:00:00      4.629630
# 2020-10-25 05:00:00     23.241935
# 2020-10-25 06:00:00     98.296774
# 2020-10-25 07:00:00    278.748387
# 2020-10-25 08:00:00    457.900000
# 2020-10-25 09:00:00    218.248387
# 2020-10-25 10:00:00    103.387097
# 2020-10-25 11:00:00    119.919355
# 2020-10-25 12:00:00    158.938907
# 2020-10-25 13:00:00    154.945338
# 2020-10-25 14:00:00    135.684887
# 2020-10-25 15:00:00    153.446945
# 2020-10-25 16:00:00    244.720257
# 2020-10-25 17:00:00    472.700965
# 2020-10-25 18:00:00    446.070740
# 2020-10-25 19:00:00    308.826367
# 2020-10-25 20:00:00    218.771704
# 2020-10-25 21:00:00    160.765273
# 2020-10-25 22:00:00    119.077170
# 2020-10-25 23:00:00     75.813505
# Name: registered, dtype: float64

# %%
no_workday.groupby('time')['casual'].mean().plot()

# %%
no_workday.groupby('time')['registered'].mean().plot()

# %%
out = df[df['count']>284]

# %%
out.describe()
# Out:
#             season      holiday  ...   registered        count
# count  2712.000000  2712.000000  ...  2712.000000  2712.000000
# mean      2.782817     0.031342  ...   361.976401   451.469027
# std       0.936785     0.174273  ...   141.777230   141.800028
# min       1.000000     0.000000  ...   109.000000   285.000000
# 25%       2.000000     0.000000  ...   258.000000   339.000000
# 50%       3.000000     0.000000  ...   323.000000   411.500000
# 75%       4.000000     0.000000  ...   429.000000   527.000000
# max       4.000000     1.000000  ...   886.000000   977.000000
#
# [8 rows x 11 columns]

# %%
out[['weather', 'temp', 'atemp', 'humidity', 'windspeed', ]].mean()
# Out:
# weather       1.299410
# temp         24.687382
# atemp        28.441794
# humidity     53.767330
# windspeed    13.736561
# dtype: float64

# %%
df.describe()
# Out:
#              season       holiday  ...    registered         count
# count  10886.000000  10886.000000  ...  10886.000000  10886.000000
# mean       2.506614      0.028569  ...    155.552177    191.574132
# std        1.116174      0.166599  ...    151.039033    181.144454
# min        1.000000      0.000000  ...      0.000000      1.000000
# 25%        2.000000      0.000000  ...     36.000000     42.000000
# 50%        3.000000      0.000000  ...    118.000000    145.000000
# 75%        4.000000      0.000000  ...    222.000000    284.000000
# max        4.000000      1.000000  ...    886.000000    977.000000
#
# [8 rows x 11 columns]

# %%
out['count'].plot()

# %%
out['season'].value_counts()
# Out:
# 3    940
# 2    813
# 4    714
# 1    245
# Name: season, dtype: int64

# %%
out.groupby('time')['count'].mean().plot()

# %%
out['time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
out.groupby('time')['registered'].mean().plot()

# %%
out.groupby('time')['casual'].mean().plot()

# %%
df.groupby('holiday')['count'].mean().plot()

# %%
df.groupby('work')

# %%
df['redday'] = df['holiday'] + 1 - df['workingday']

# %%
df.groupby('workingday')['count'].mean()
# Out:
# workingday
# 0    188.506621
# 1    193.011873
# Name: count, dtype: float64

# %%
df['workingday'].value_counts()
# Out:
# 1    7412
# 0    3474
# Name: workingday, dtype: int64

# %%
df['workingday'].mean()
# Out:
# 0.6808745177291935

# %%
df['casual'].mean()
# Out:
# 36.02195480433584

# %%
df['registered'].mean()
# Out:
# 155.5521771082124
